# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('World_happiness_report.csv')

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.head(30)
# Out:
#                  Country                           Region  Happiness Rank  \
# 0            Switzerland                   Western Europe               1
# 1                Iceland                   Western Europe               2
# 2                Denmark                   Western Europe               3
# 3                 Norway                   Western Europe               4
# 4                 Canada                    North America               5
# 5                Finland                   Western Europe               6
# 6            Netherlands                   Western Europe               7
# 7                 Sweden                   Western Europe               8
# 8            New Zealand        Australia and New Zealand               9
# 9              Australia        Australia and New Zealand              10
# 10                Israel  Middle East and Northern Africa              11
# 11            Costa Rica      Latin America and Caribbean              12
# ...

# %%
data.tail(30)
# Out:
#                       Country                           Region  \
# 128                   Myanmar                Southeastern Asia
# 129                   Georgia       Central and Eastern Europe
# 130                    Malawi               Sub-Saharan Africa
# 131                 Sri Lanka                    Southern Asia
# 132                  Cameroon               Sub-Saharan Africa
# 133                  Bulgaria       Central and Eastern Europe
# 134                     Egypt  Middle East and Northern Africa
# 135                     Yemen  Middle East and Northern Africa
# 136                    Angola               Sub-Saharan Africa
# 137                      Mali               Sub-Saharan Africa
# 138       Congo (Brazzaville)               Sub-Saharan Africa
# 139                   Comoros               Sub-Saharan Africa
# 140                    Uganda               Sub-Saharan Africa
# 141                   Senegal               Sub-Saharan Africa
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %%
sns.barplot(x='Happiness Rank',y='Country',data=data.nsmallest(20,'Happiness Rank'))

# %%
sns.barplot(x='Happiness Rank',y='Happiness Score',data=data.nlargest(15,'Happiness Score'))

# %%
# we can observe in the barplot that happiness rank is proportional to happiness score.

# %%
data['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Economy (GDP per Capita)',y='Country',data=data.nlargest(30,'Economy (GDP per Capita)'))

# %% [markdown]
# Observations:
#     Qatar, Luxembourg, Singapore, Norway, United Aarab Emirates, Switzerland, Oman, United States, Austria, Ireland, Australia, Sweden, Netherlands, Germany, Canada, Denmark, Belgium, Iceland, Finland, France, United Kingdom, New Zealand. These 22 out of 30 countries are listed in the top list for both the Happiness Rank amd the Economy. We can say that countries having a higher GDP are ranked above in Happiness Ranking 73.33% of the times.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Economy (GDP per Capita)',y='Country',data=data.nsmallest(30,'Economy (GDP per Capita)'))

# %% [markdown]
# Observations:
#     Congo, Burundi, Malawi, Niger, Central African Republic, Guinea, Madagascar, Togo, Uganda, Rwanda, Comoros, Burkina Faso, Mali, Myanmar, Tanzania, Benin, Afghanistan, Chad, Senegal. We can see that 19 out of 30 countries with lowest Gdp are also ranked in the least 30 Happiness ranking. So 63.33% of the time we can observe the Economy is cintributing to the Happiness ranking.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Family',y='Country',data=data.nlargest(30,'Family'))

# %% [markdown]
# Observations:
#     Iceland, Ireland, Denmark, Switzerland, Norway, Canada, New Zealand, Finland, Australia, Germany,  Austria, Sweden, Belgium, United Kingdom, Netherlands, France, Venezuela, Argentina, United States. These 19 out of 30 countries have a good family rating and also lies in top 30 Happiness Ranked countries. So we concluded that 63.33% of the times countries rated a high Family rating are in the higher Happiness Ranks.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Family',y='Country',data=data.nsmallest(30,'Family'))

# %% [markdown]
# Observations:
#     Central African Republic, Togo, Afghanistan, Georgia, Benin, Malawi, Burundi, Guinea, Syria, Cambodia, Congo, Madagascar, Yemen, Myanmar, Egypt, Chad, Ivory Coast, Niger, Rwanda. These countries are also ranked in the least 30 in Happiness index. We can 63.33% times say that a country having a low family rating would have a low happiness rank.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Health (Life Expectancy)',y='Country',data=data.nlargest(30,'Health (Life Expectancy)'))

# %% [markdown]
# Observation:
#     Singapore, Iceland, France, Switzerland, Australia, Luxembourg, Israel, Sweden, United Kingdom, New Zealand, Canada, Belgium, Ireland, Netherlands, Germany, Austria, Finland, Norway, Denmark.
#     19 out of the 30 countires listed in the above plot bear a happiness ranking of top 30. So 63.33% of the data reflects that a good life expectancy can contribute to the Happiness Ranking of the country in particular.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Health (Life Expectancy)',y='Country',data=data.nsmallest(30,'Health (Life Expectancy)'))

# %% [markdown]
# Observations: Central African Republic, Chad, Ivory coast, Angola, Mali, Burundi, Malawi, Cameroon, Guinea, Burkina Faso, Togo, Niger, Afghanistan, Congo, Benin, Uganda, Comoros. So 17 out of 30 countries listed here are also in the least 30 happiness ranked countries. So 56.66% of the time we can say that a country scoring less in the Health facgtor will also have a lower happiness rank.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Freedom',y='Country',data=data.nlargest(30,'Freedom'))

# %% [markdown]
# Observations:
#     Norway, Switzerland, Sweden, Australia, Denmark, Finland, United Arab Emirates, Qatar, New Zealand, Costa Rica, Canada, Oman, Iceland, Austria, Ireland, Luxembourg, Netherlands, Germany, United kingdom. 19 out of 30 countires with a good freedom score lies in the top 30 Happines Ranked countires. So this tells us that a country with good freedom score would have a higher happines ranking 63.33% of the time.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Freedom',y='Country',data=data.nsmallest(30,'Freedom'))

# %% [markdown]
# Observations:
#     Angola, Burundi, Syria, Egypt, Madagascar, Congo, Comoros, Afghanistan, Chad. These 9 countries are also listed in the 30 least happiest countries. So 30% of the times we can observe a lower freedom score corresponding to a lower happiness ranking.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Trust (Government Corruption)',y='Country',data=data.nlargest(30,'Trust (Government Corruption)'))

# %% [markdown]
# Observations:
# Qatar, Singapore, Denmark, Sweden, New Zealand, Switzerland, Finland, United Arab Emirates, Luxembourg, Norway, Australia, Canada, Oman, United Kingdom, Netherlands, Ireland, Belgium, Germany. 18 out of 30 countries with a trust on goverment falls in the top 30 of the happiness ranking. 60% of the time the information of the Trust column supports the Happiness ranking.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Trust (Government Corruption)',y='Country',data=data.nsmallest(30,'Trust (Government Corruption)'))

# %% [markdown]
# Observations:
#     There is only one country in this list of 30 countries that would also fall in the least 30 happiness ranked countries. So this data is not clearly contributing to the ranking of the happiness.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Generosity',y='Country',data=data.nlargest(30,'Generosity'))

# %% [markdown]
# Obseravations:
#     United Kingdom, Netherlands, New Zealand, Ireland, Canada, Iceland, Australia, UnitedSates, Sweden, Norway, Denmrak. These 11 out of 30 countries also are the countries in the top 30 happiness ranked list. So only 36.66% of the time we can say that a country with a higher generosity score would rank good in the happiness ranking.

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Generosity',y='Country',data=data.nsmallest(30,'Generosity'))

# %% [markdown]
# Observation:
#      Gabon, Yemen, Egypt, Bulgaria are the only country falling in this list of lowest Generosity which also fall in the list of the 30 least happiness ranked country. So this data is not clearly confirming the relation of generosity with the happiness ranking.

# %%
plt.figure(figsize=(30,30))
sns.barplot(x='Dystopia Residual',y='Country',data=data)

# %%
#Dystopia residual column is not giving any direction to the happiness ranking of the coutnries. We can consider dropping it.

# %%
plt.figure(figsize=(30,30))
sns.barplot(x='Standard Error',y='Country',data=data)

# %%
#Dystopia residual column is not giving any direction to the happiness ranking of the coutnries. We can consider dropping it.

# %%
data.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
sns.heatmap(data.corr())

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# Observations:
#     1. In Standard error, Trust, Generosity column, there is a good difference in the 75% and max, the data is positively skewed.
#     2. In Family and Health column, min and 25% have a good difference the data seems to be negatively skewed.

# %%
data.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.boxplot(y=data['Economy (GDP per Capita)'])

# %%
sns.boxplot(y=data['Family'])

# %%
sns.boxplot(y=data['Health (Life Expectancy)'])

# %%
sns.boxplot(y=data['Freedom'])

# %%
sns.boxplot(y=data['Trust (Government Corruption)'])

# %%
sns.boxplot(y=data['Generosity'])

# %% [markdown]
# The presence of outliers can be observed in: Family, Trust (Government Corruption) and Genorosity

# %%
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#Dropping certain columns
data=data.drop(['Region','Dystopia Residual',"Generosity",'Trust (Government Corruption)','Standard Error'],axis=1)

# %%
data
# Out:
#          Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    Switzerland               1            7.587                   1.39651
# 1        Iceland               2            7.561                   1.30232
# 2        Denmark               3            7.527                   1.32548
# 3         Norway               4            7.522                   1.45900
# 4         Canada               5            7.427                   1.32629
# ..           ...             ...              ...                       ...
# 153       Rwanda             154            3.465                   0.22208
# 154        Benin             155            3.340                   0.28665
# 155        Syria             156            3.006                   0.66320
# 156      Burundi             157            2.905                   0.01530
# 157         Togo             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data['Country']=le.fit_transform(data['Country'].astype(str))

# %%
data
# Out:
#      Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0        135               1            7.587                   1.39651
# 1         58               2            7.561                   1.30232
# 2         37               3            7.527                   1.32548
# 3        105               4            7.522                   1.45900
# 4         24               5            7.427                   1.32629
# ..       ...             ...              ...                       ...
# 153      118             154            3.465                   0.22208
# 154       13             155            3.340                   0.28665
# 155      136             156            3.006                   0.66320
# 156       21             157            2.905                   0.01530
# 157      141             158            2.839                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom
# 0    1.34951                   0.94143  0.66557
# ...

# %%
data.describe()
# Out:
#           Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# count  158.000000      158.000000       158.000000                158.000000
# mean    78.500000       79.493671         5.375734                  0.846137
# std     45.754781       45.754363         1.145010                  0.403121
# min      0.000000        1.000000         2.839000                  0.000000
# 25%     39.250000       40.250000         4.526000                  0.545808
# 50%     78.500000       79.500000         5.232500                  0.910245
# 75%    117.750000      118.750000         6.243750                  1.158448
# max    157.000000      158.000000         7.587000                  1.690420
#
#            Family  Health (Life Expectancy)     Freedom
# count  158.000000                158.000000  158.000000
# mean     0.991046                  0.630259    0.428615
# std      0.272369                  0.247078    0.150693
# ...

# %%
data.skew()
# Out:
# Country                     0.000000
# Happiness Rank              0.000418
# Happiness Score             0.097769
# Economy (GDP per Capita)   -0.317575
# Family                     -1.006893
# Health (Life Expectancy)   -0.705328
# Freedom                    -0.413462
# dtype: float64

# %%
#removing skewness using power transform
from sklearn.preprocessing import PowerTransformer

# %%
pt=PowerTransformer(method='yeo-johnson')

# %%
data_new=pt.fit_transform(data)

# %%
data_new
# Out:
# array([[ 1.17106926, -2.06341393,  1.85703444, ...,  1.66920633,
#          1.49176451,  1.75633466],
#        [-0.3443269 , -2.00849761,  1.83666843, ...,  2.01213244,
#          1.53234848,  1.43994643],
#        [-0.84509236, -1.95857395,  1.81000179, ...,  1.73958573,
#          1.08522306,  1.6157332 ],
#        ...,
#        [ 1.18876946,  1.52535242, -2.20718029, ..., -1.69066357,
#          0.26293312, -1.66865772],
#        [-1.28332767,  1.54254416, -2.3121775 , ..., -1.79680304,
#         -1.52569971, -1.84990313],
#        [ 1.27672507,  1.55970548, -2.38132668, ..., -2.16039658,
#         -1.37181091, -0.50836227]])

# %%
happiness=pd.DataFrame(data=data_new,columns=data.columns)

# %%
happiness
# Out:
#       Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0    1.171069       -2.063414         1.857034                  1.446061
# 1   -0.344327       -2.008498         1.836668                  1.173321
# 2   -0.845092       -1.958574         1.810002                  1.239836
# 3    0.620972       -1.912062         1.806077                  1.630246
# 4   -1.195601       -1.868100         1.731344                  1.242168
# ..        ...             ...              ...                       ...
# 153  0.864172        1.490877        -1.741699                 -1.494046
# 154 -1.536462        1.508130        -1.866654                 -1.360829
# 155  1.188769        1.525352        -2.207180                 -0.513469
# 156 -1.283328        1.542544        -2.312178                 -1.894954
# 157  1.276725        1.559705        -2.381327                 -1.521226
#
#        Family  Health (Life Expectancy)   Freedom
# ...

# %%
happiness.skew()
# Out:
# Country                    -0.279791
# Happiness Rank             -0.264365
# Happiness Score            -0.027956
# Economy (GDP per Capita)   -0.127233
# Family                     -0.169651
# Health (Life Expectancy)   -0.183181
# Freedom                    -0.080728
# dtype: float64

# %%
sns.boxplot(y=happiness['Family'])

# %%
#outliers are removed from the columns after removing the skewness.

# %%
x=happiness.drop('Happiness Rank',axis=1)

# %%
x
# Out:
#       Country  Happiness Score  Economy (GDP per Capita)    Family  \
# 0    1.171069         1.857034                  1.446061  1.669206
# 1   -0.344327         1.836668                  1.173321  2.012132
# 2   -0.845092         1.810002                  1.239836  1.739586
# 3    0.620972         1.806077                  1.630246  1.553118
# 4   -1.195601         1.731344                  1.242168  1.501726
# ..        ...              ...                       ...       ...
# 153  0.864172        -1.741699                 -1.494046 -0.959885
# 154 -1.536462        -1.866654                 -1.360829 -1.896644
# 155  1.188769        -2.207180                 -0.513469 -1.690664
# 156 -1.283328        -2.312178                 -1.894954 -1.796803
# 157  1.276725        -2.381327                 -1.521226 -2.160397
#
#      Health (Life Expectancy)   Freedom
# 0                    1.491765  1.756335
# 1                    1.532348  1.439946
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 1.17106926e+00,  1.85703444e+00,  1.44606102e+00,
#          1.66920633e+00,  1.49176451e+00,  1.75633466e+00],
#        [-3.44326902e-01,  1.83666843e+00,  1.17332111e+00,
#          2.01213244e+00,  1.53234848e+00,  1.43994643e+00],
#        [-8.45092357e-01,  1.81000179e+00,  1.23983558e+00,
#          1.73958573e+00,  1.08522306e+00,  1.61573320e+00],
#        [ 6.20972247e-01,  1.80607695e+00,  1.63024553e+00,
#          1.55311811e+00,  1.14759963e+00,  1.79282102e+00],
#        [-1.19560132e+00,  1.73134406e+00,  1.24216836e+00,
#          1.50172605e+00,  1.27017856e+00,  1.47547945e+00],
#        [-6.46799964e-01,  1.71478264e+00,  1.13879939e+00,
#          1.47510960e+00,  1.17079907e+00,  1.54972572e+00],
#        [ 5.05883695e-01,  1.69267718e+00,  1.25124448e+00,
#          1.24751108e+00,  1.19308059e+00,  1.33081553e+00],
#        [ 1.15333190e+00,  1.68161432e+00,  1.25778915e+00,
#          1.29981977e+00,  1.30207755e+00,  1.70597065e+00],
# ...

# %%
x=pd.DataFrame(data=x,columns=('Country','Happiness Score','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom'))

# %%
x
# Out:
#       Country  Happiness Score  Economy (GDP per Capita)    Family  \
# 0    1.171069         1.857034                  1.446061  1.669206
# 1   -0.344327         1.836668                  1.173321  2.012132
# 2   -0.845092         1.810002                  1.239836  1.739586
# 3    0.620972         1.806077                  1.630246  1.553118
# 4   -1.195601         1.731344                  1.242168  1.501726
# ..        ...              ...                       ...       ...
# 153  0.864172        -1.741699                 -1.494046 -0.959885
# 154 -1.536462        -1.866654                 -1.360829 -1.896644
# 155  1.188769        -2.207180                 -0.513469 -1.690664
# 156 -1.283328        -2.312178                 -1.894954 -1.796803
# 157  1.276725        -2.381327                 -1.521226 -2.160397
#
#      Health (Life Expectancy)   Freedom
# 0                    1.491765  1.756335
# 1                    1.532348  1.439946
# ...

# %%
y=data['Happiness Rank']

# %%
y
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 153    154
# 154    155
# 155    156
# 156    157
# 157    158
# Name: Happiness Rank, Length: 158, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.metrics import r2_score
list=[LinearRegression(),SVR(kernel='linear'),DecisionTreeRegressor(),KNeighborsRegressor(),RandomForestRegressor(),AdaBoostRegressor()]
for j in list:
    r_max=0
    print('for the algorithm: ',j)
    for i in range(33,101):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
        j.fit(x_train,y_train)
        pred=j.predict(x_test)
        r2_scr=r2_score(pred,y_test)
        print('r2 score corresponding to random state',i,'is: ',r2_scr)
        if r2_scr>r_max:
            r_max=r2_scr
            final=i
    print('\n')
    print('Max r2 score corresponding to: ', final,'is: ',r_max)
    print('\n')
# Out:
# for the algorithm:  LinearRegression()
# r2 score corresponding to random state 33 is:  0.9787883681855605
# r2 score corresponding to random state 34 is:  0.9836508959415068
# r2 score corresponding to random state 35 is:  0.986911794110198
# r2 score corresponding to random state 36 is:  0.9713576114189307
# r2 score corresponding to random state 37 is:  0.9879481790802024
# r2 score corresponding to random state 38 is:  0.9797747123151428
# r2 score corresponding to random state 39 is:  0.9791292049164393
# r2 score corresponding to random state 40 is:  0.9869724540541811
# r2 score corresponding to random state 41 is:  0.9805026812592426
# r2 score corresponding to random state 42 is:  0.9811263059480007
# r2 score corresponding to random state 43 is:  0.9818594088760391
# r2 score corresponding to random state 44 is:  0.9792989406939097
# r2 score corresponding to random state 45 is:  0.9875257731492966
# r2 score corresponding to random state 46 is:  0.9769659308780496
# ...

# %%
param = {
    'kernel':['linear','poly','rbf']
}



svr=SVR()

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
cv = GridSearchCV(svr, param_grid=param)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=70)
cv.fit(x_train, y_train)
print(cv.best_score_)
print(cv.best_estimator_)
print(cv.best_params_)
# Out:
# 0.9475673157912686
# SVR(kernel='linear')
# {'kernel': 'linear'}

# %% [markdown]
# we observed in grid search cv that the model is performing better with kernel=linear. So we proceed further and save this model into joblib.

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
sv=SVR(kernel='linear')
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=70)
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
print('R2 score: ', r2_score(pred,y_test))
print('Mean Squared Error: ',mean_squared_error(pred,y_test))
print('Root Mean Squared Error: ', np.sqrt(mean_squared_error(pred,y_test)))
# Out:
# R2 score:  0.9792611746634547
# Mean Squared Error:  39.95589964149199
# Root Mean Squared Error:  6.321067919386089

# %%
import joblib

# %%
joblib.dump(sv,'happiness_sv.obj')
# Out:
# ['happiness_sv.obj']
